# %% [markdown]
# # Julia 基礎圖表繪製: Plots 套件
#
# ## 作業 023：繪製 3D 函數
#
# 練習繪製 3D 函數：$z = x^2 - y^2$，$x$ 範圍於 $-5 \sim 5$，$y$ 範圍於 $-5 \sim 5$ 之間。（請完成以下程式碼）

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
n = 1000
x = range(-5.,stop=5., length=n)
y = range(-5.,stop=5., length=n)
# Out:
# -5.0:0.01001001001001001:5.0

# %%
f(x,y) = x^2-y^2
# Out:
# f (generic function with 1 method)

# %%
p = plot(x, y, f, st=:surface)

# %% [markdown]
# ## 3D animation

# %%
@gif for i in range(0, stop=2pi, length=100)
    p= plot(x, y, f, st=:surface)
    plot!(p,camera=(15*cos(i), 40))
end
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\chris-wang\Documents\GitHub\1st-JuliaMarathon\tmp.gif
# └ @ Plots C:\Users\chris-wang\.julia\packages\Plots\EJmJT\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\chris-wang\\Documents\\GitHub\\1st-JuliaMarathon\\tmp.gif")

# %%
p=plot(1)
ani= @animate for i in range(0, stop=2pi, length=100)
    p= plot(x, y, f, st=:surface)
    plot!(p,camera=(15*cos(i), 40))
end
gif(ani, "animate.gif", fps=45)
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\chris-wang\Documents\GitHub\1st-JuliaMarathon\animate.gif
# └ @ Plots C:\Users\chris-wang\.julia\packages\Plots\EJmJT\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\chris-wang\\Documents\\GitHub\\1st-JuliaMarathon\\animate.gif")
